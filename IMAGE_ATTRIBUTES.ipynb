# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhagyalata-cse/Bhagyalata-cse/blob/main/IMAGE_ATTRIBUTES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
url ="https://outdoormichigan.org/images/CoolboughNaturalAreasBigelowCreek.jpg"
image = io.imread(url)  
cv2_imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))
# Out:
# <PIL.Image.Image image mode=RGB size=800x599 at 0x7FCB93928450>

# %%
# Check the image matrix data type (could know the bit depth of the image)
print(image.dtype)
# Check the height of image 
print(image.shape[0])
# Check the width of image 
print(image.shape[1])
# Check the number of channels of the image
print(image.shape[2])
# Out:
# uint8
# 599
# 800
# 3

# %%
plt.hist(image.ravel(),bins = 256, range = [0,256]) 
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv.calcHist([image],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=800x599 at 0x7FCB91DAF610>

# %%
plt.hist(gray_image.ravel(),bins = 256, range = [0, 256])
plt.show()

# %%
plt.contour(gray_image, origin = "image")

# %%
print(image.shape)
# Out:
# (599, 800, 3)

# %%
print(gray_image.shape)
# Out:
# (599, 800)

# %%
print(image[100][50])
# Out:
# [150 108  66]

# %%
print(gray_image[100][50])
# Out:
# 100

# %%
print(image[500][100])
print(gray_image[500][100])
# Out:
# [254 255 249]
# 253

# %%
print(image[100][100])
print(gray_image[100][100])
# Out:
# [57 52 30]
# 46

# %%
print(image[100][150])
print(gray_image[100][150])
print(image[100][200])
print(gray_image[100][200])
print(image[100][250])
print(gray_image[100][250])
print(image[100][300])
print(gray_image[100][300])
print(image[100][350])
print(gray_image[100][350])
print(image[100][400])
print(gray_image[100][400])
print(image[150][500])
print(gray_image[150][500])
print(image[250][500])
print(gray_image[250][500])

print(image[150][400])
print(gray_image[150][400])
print(image[150][300])
print(gray_image[150][300])
print(image[100][500])
print(gray_image[100][500])
print(image[200][200])
print(gray_image[200][200])
print(image[300][200])
print(gray_image[300][200])
# Out:
# [113  70  27]
# 62
# [107  75  36]
# 67
# [153 100  69]
# 97
# [135 143 120]
# 135
# [55 70 27]
# 55
# [182 203 146]
# 184
# [54 69 30]
# 56
# [54 70 33]
# 57
# [104 126  80]
# 110
# [142 150  90]
# 131
# [21 44  0]
# 28
# [98 70 23]
# 59
# [85 96 54]
# 82

# %%
print(image[150][300])
print(gray_image[150][300])
# Out:
# [142 150  90]
# 131

# %%
print(gray_image[290][750])
print(image[290][750])
# Out:
# 44
# [45 54 23]

# %%
print(gray_image[490][750])
print(gray_image[590][790])
print(gray_image[190][400])
print(gray_image[290][450])
print(gray_image[90][455])
print(gray_image[80][755])
print(gray_image[99][55])
print(gray_image[100][355])
print(gray_image[50][455])
print(gray_image[79][655])
print(gray_image[94][155])
# Out:
# 131
# 126
# 45
# 42
# 166
# 80
# 97
# 80
# 172
# 146
# 78

# %%
print(image[94][455])
print(gray_image[94][455])
# Out:
# [164 192 107]
# 163

# %%
print(gray_image[100][69])
# Out:
# 27

# %%
print(gray_image[94][68])
print(image[94][68])
# Out:
# 0
# [3 0 0]

# %%
print(image[490][750])

#printimage[590][790])
print(image[190][400])
print(image[290][450])
print(image[90][455])
print(image[80][755])
print(image[99][55])
print(image[100][355])
print(image[50][455])
print(image[79][655])
print(image[94][155])
print(image[100][69])
# Out:
# [164 156  71]
# [45 68  0]
# [49 59  7]
# [167 187 126]
# [ 82 103  34]
# [159  99  71]
# [78 99 42]
# [178 204 107]
# [147 160 117]
# [116  87  45]
# [28 32 17]
